# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
import random
import sklearn as sk
import sklearn.model_selection as skm

random.seed(786)
np.random.seed(786)


gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)


from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Fri Nov 25 13:28:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/Colab Notebooks/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %%
def LSTM1(nodes,nodes2, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)


def LSTM2(nodes,nodes2, nodes3, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(LSTM(nodes3, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

def LSTM3(nodes,nodes2, nodes3,nodes4, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(LSTM(nodes3, return_sequences=True))
    model.add(LSTM(nodes4, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,nodes4,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

def LSTM1D1(nodes,nodes2, nodes3, activation, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(Dense(nodes3, activation= activation))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,activation, dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

def LSTM1D2(nodes,nodes2, nodes3,nodes4,activation, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(Dense(nodes3, activation= activation))
    model.add(Dense(nodes4, activation= activation))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,nodes4,activation,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

# %%
# dropout at the end is here 
# https://www.researchgate.net/publication/308849574_Where_to_apply_dropout_in_recurrent_neural_networks_for_handwriting_recognition

# %%
def generate_train_data(nqts):
  ntrain =nqts
  ntest = nqts
  total_qts = 40 - ntrain - ntest

  df = pd.read_csv('full_dataset.csv')
  df = df[df['Time']<(total_qts+1)]
  df= df.sort_values(by=['Ticker', 'Time'])
  df = df.reset_index()
  df = df.iloc[:,1:]
  df = df.astype(float)
  scaler = StandardScaler()
  scaler = scaler.fit(df.iloc[:,3:])

  #empty lists
  splitdfY= []
  splitdfX= []

  #append all firms
  x=0
  for i in range(0,127):
      splitdfY.append(df.iloc[x:x+total_qts, :])
      x= x+total_qts
  #
  x=0
  for i in range(0,127):
      df_append = df.iloc[x:x+total_qts, :]
      splitdfX.append(df_append)
      x= x+total_qts
      
  #scale and transform to numpy and set the correct train and test
  trainX = []
  trainY = []
  stride = 1
  y= (((total_qts - ntrain -ntest)/stride)+1)

  for j in range(0,127):
      x=ntest
      for i in range(0,int(y)):
          #trainY.append(pd.DataFrame.to_numpy(splitdf[j].iloc[x:x+ntrain,:1]))
          trainY.append(splitdfY[j].iloc[x:x+ntrain,:1])
          x+= stride

  # 
  for j in range(0,127):
      x=0
      for i in range(0,int(y)):
          df_sc_ap = splitdfX[j].iloc[x:x+ntrain,3:]
          dfX = scaler.transform(df_sc_ap)
          trainX.append(dfX)
          #trainX.append(pd.DataFrame.to_numpy(splitdfX[j].iloc[x:x+ntrain,3:]))
          x+= stride
          
  #finalise the formatting
  trainX = np.array(trainX)
  print('trainX shape == {}.'.format(trainX.shape))

  trainY = np.array(trainY)
  trainY = to_categorical(trainY)
  trainY= trainY[:,:, 1:]
  print('trainY shape == {}.'.format(trainY.shape))

  return trainX, trainY

# %%
def run_all_models_FO(nqts, epochs):
  nqts = nqts
  

  #LSTM1 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']

  grid1 = skm.ParameterGrid(param_grid_lstm1)
  results_df = pd.DataFrame(columns= columns)
  run_no =1
  #run model and tune
  for params in grid1:
      run = LSTM1(nodes=124,\
                        nodes2 = params['nodes2'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no, "of LSTM1")
  results_df.to_csv("LSTM1_FO_{}.csv".format(nqts))

  #LSTM2 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  run_no =1

  grid2 = skm.ParameterGrid(param_grid_lstm2)

  #run model and tune
  for params in grid2:
      run = LSTM2(nodes=124,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no , "of LSTM2")
  results_df.to_csv("LSTM2_FO_{}.csv".format(nqts))

  #LSTM3 ------------------------------------------------------------------------------------------------------------------

  #initialize the empty results dataframe
  columns = ['nodes','nodes2','nodes3','nodes4','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  run_no =1

  grid3 = skm.ParameterGrid(param_grid_lstm3)
  #run model and tune
  for params in grid3:
      run = LSTM3(nodes=124,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        nodes4 = params['nodes4'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)    
      run_no +=1
      print(run_no, "of LSTM3")
  results_df.to_csv("LSTM3_FO_{}.csv".format(nqts))


  #LSTM1D1 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','activation','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  #initialize loading variables batch size of 64
  run_no =1
  grid4 = skm.ParameterGrid(param_grid_lstm1d1)
  #run model and tune
  for params in grid4:
      run = LSTM1D1(nodes=124,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        activation = params['activation'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no, "of LSTM1D1")
  results_df.to_csv("LSTM1D1_FO_{}.csv".format(nqts))


  #LSTM1D2 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','nodes4','activation','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  grid5 = skm.ParameterGrid(param_grid_lstm1d2)
  #initialize loading variables
  run_no =1
  #run model and tune
  for params in grid5:
      run = LSTM1D2(nodes=124,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        nodes4 = params['nodes4'],\
                        activation = params['activation'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      
      run_no +=1
      print(run_no, "of LSTM1D2")
  results_df.to_csv("LSTM1D2_FO_{}.csv".format(nqts))

# %%
param_grid_lstm1 = {'nodes2': [20, 50, 75, 100, 124],\
              'dropout' : [0.4, 0.6],\
              'optimizer' : ['Adam'],\
              'batchsize' : [16]}

param_grid_lstm2 = {'nodes2': [20, 50, 75, 100, 124],\
              'nodes3': [20, 50, 75, 100, 124],\
              'dropout' : [0.4, 0.6],\
              'optimizer' : ['Adam'],\
              'batchsize' : [16]}

param_grid_lstm3 = {'nodes2': [20, 50, 75, 100],\
              'nodes3': [20, 50, 75, 100],\
              'nodes4': [20, 50, 75, 100],\
              'dropout' : [0.4, 0.6],\
              'optimizer' : ['Adam'],\
              'batchsize' : [16]}

param_grid_lstm1d1 = {'nodes2': [20, 50, 75, 100],\
              'nodes3': [20, 50, 75, 100],\
              'activation': ['tanh', 'relu'],\
              'dropout' : [0.4, 0.6],\
              'optimizer' : ['Adam'],\
              'batchsize' : [16]}

param_grid_lstm1d2 = {'nodes2': [20, 50, 75, 100],\
              'nodes3': [20, 50, 75, 100],\
              'nodes4': [20, 50, 75, 100],\
              'activation': ['tanh', 'relu'],\
              'dropout' : [0.4, 0.6],\
              'optimizer' : ['Adam'],\
              'batchsize' : [16]}

# %%
trainX, trainY = generate_train_data(4)
run_all_models_FO(4,10)
print("done with 4")

trainX, trainY = generate_train_data(6)
run_all_models_FO(6,10)
print("done with 6")

trainX, trainY = generate_train_data(8)
run_all_models_FO(8,10)
print("done with 8")

trainX, trainY = generate_train_data(10)
run_all_models_FO(10, 10)
print("done with 10")

# %% [markdown]
# This marks the end of the section of the code dealing with regular modeling
# The next section deals with running the models with feature selection

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
import random
import sklearn as sk
import sklearn.model_selection as skm

random.seed(786)
np.random.seed(786)


gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)


from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Sat Feb 18 11:20:53 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    25W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/Colab Notebooks/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %%
def LSTM1(nodes,nodes2, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)


def LSTM2(nodes,nodes2, nodes3, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(LSTM(nodes3, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

def LSTM3(nodes,nodes2, nodes3,nodes4, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(LSTM(nodes3, return_sequences=True))
    model.add(LSTM(nodes4, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,nodes4,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

def LSTM1D1(nodes,nodes2, nodes3, activation, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(Dense(nodes3, activation= activation))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,activation, dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

def LSTM1D2(nodes,nodes2, nodes3,nodes4,activation, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(Dense(nodes3, activation= activation))
    model.add(Dense(nodes4, activation= activation))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,nodes4,activation,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

# %%
def generate_train_data_with_fs(nqts, nfts):
  ntrain =nqts
  ntest = nqts
  feature_cols = nfts + 3

  total_qts = 40 - ntrain - ntest


  var_imp_file_name = 'varimp_{}.csv'.format(total_qts)
  print(var_imp_file_name)
  varimp =  pd.read_csv(var_imp_file_name)

  df = pd.read_csv('full_dataset.csv')
  df = df[df['Time']<(total_qts+1)]
  df = df[df.columns.intersection(varimp.iloc[0:feature_cols,0])]
  df= df.sort_values(by=['Ticker', 'Time'])
  df = df.reset_index()
  df = df.iloc[:,1:]
  df = df.astype(float)
  scaler = StandardScaler()
  scaler = scaler.fit(df.iloc[:,3:])

  #empty lists
  splitdfY= []
  splitdfX= []

  #append all firms
  x=0
  for i in range(0,127):
      splitdfY.append(df.iloc[x:x+total_qts, :])
      x= x+total_qts
  #
  x=0
  for i in range(0,127):
      df_append = df.iloc[x:x+total_qts, :]
      splitdfX.append(df_append)
      x= x+total_qts
      
  #scale and transform to numpy and set the correct train and test
  trainX = []
  trainY = []
  stride = 1
  y= (((total_qts - ntrain -ntest)/stride)+1)

  for j in range(0,127):
      x=ntest
      for i in range(0,int(y)):
          #trainY.append(pd.DataFrame.to_numpy(splitdf[j].iloc[x:x+ntrain,:1]))
          trainY.append(splitdfY[j].iloc[x:x+ntrain,:1])
          x+= stride

  # 
  for j in range(0,127):
      x=0
      for i in range(0,int(y)):
          df_sc_ap = splitdfX[j].iloc[x:x+ntrain,3:]
          dfX = scaler.transform(df_sc_ap)
          trainX.append(dfX)
          #trainX.append(pd.DataFrame.to_numpy(splitdfX[j].iloc[x:x+ntrain,3:]))
          x+= stride
          
  #finalise the formatting
  trainX = np.array(trainX)
  print('trainX shape == {}.'.format(trainX.shape))

  trainY = np.array(trainY)
  trainY = to_categorical(trainY)
  trainY= trainY[:,:, 1:]
  print('trainY shape == {}.'.format(trainY.shape))

  return trainX, trainY

# %%
def run_all_models_FO(nqts, epochs, nfts):
  nqts = nqts

  feature_nodes = nfts+1 
  

  #LSTM1 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']

  grid1 = skm.ParameterGrid(param_grid_lstm1)
  results_df = pd.DataFrame(columns= columns)
  run_no =1
  #run model and tune
  for params in grid1:
      run = LSTM1(nodes=feature_nodes,\
                        nodes2 = params['nodes2'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no, "of LSTM1")
  results_df.to_csv("LSTM1_FO_{q}_{f}.csv".format(q = nqts, f= nfts))

  #LSTM2 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  run_no =1

  grid2 = skm.ParameterGrid(param_grid_lstm2)

  #run model and tune
  for params in grid2:
      run = LSTM2(nodes=feature_nodes,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no , "of LSTM2")
  results_df.to_csv("LSTM2_FO_{q}_{f}.csv".format(q = nqts, f= nfts))

  #LSTM3 ------------------------------------------------------------------------------------------------------------------

  #initialize the empty results dataframe
  columns = ['nodes','nodes2','nodes3','nodes4','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  run_no =1

  grid3 = skm.ParameterGrid(param_grid_lstm3)
  #run model and tune
  for params in grid3:
      run = LSTM3(nodes=feature_nodes,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        nodes4 = params['nodes4'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)    
      run_no +=1
      print(run_no, "of LSTM3")
  results_df.to_csv("LSTM3_FO_{q}_{f}.csv".format(q = nqts, f= nfts))


  #LSTM1D1 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','activation','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  #initialize loading variables batch size of 64
  run_no =1
  grid4 = skm.ParameterGrid(param_grid_lstm1d1)
  #run model and tune
  for params in grid4:
      run = LSTM1D1(nodes=feature_nodes,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        activation = params['activation'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no, "of LSTM1D1")
  results_df.to_csv("LSTM1D1_FO_{q}_{f}.csv".format(q = nqts, f= nfts))


  #LSTM1D2 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','nodes4','activation','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  grid5 = skm.ParameterGrid(param_grid_lstm1d2)
  #initialize loading variables
  run_no =1
  #run model and tune
  for params in grid5:
      run = LSTM1D2(nodes=feature_nodes,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        nodes4 = params['nodes4'],\
                        activation = params['activation'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      
      run_no +=1
      print(run_no, "of LSTM1D2")
  results_df.to_csv("LSTM1D2_FO_{q}_{f}.csv".format(q = nqts, f= nfts))

# %%
features_list = [5, 10, 25, 50, 75]

# 2qts
param_grid_lstm1 = {
    "nodes2": [20, 50, 75],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm2 = {
    "nodes2": [50, 75, 100],
    "nodes3": [50, 75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm3 = {
    "nodes2": [75, 100],
    "nodes3": [50, 75],
    "nodes4": [75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d1 = {
    "nodes2": [20, 50, 75, 100],
    "nodes3": [10, 50, 75, 100],
    "activation": ["tanh", "relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d2 = {
    "nodes2": [50, 75, 100],
    "nodes3": [20, 50, 75],
    "nodes4": [20, 50, 100, 124],
    "activation": ["relu"],
    "dropout": [0.2, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

for features in features_list:
    trainX, trainY = generate_train_data_with_fs(2, features)
    run_all_models_FO(2, 10, features)


# 4qts
param_grid_lstm1 = {
    "nodes2": [75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm2 = {
    "nodes2": [75, 100],
    "nodes3": [75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm3 = {
    "nodes2": [50, 75],
    "nodes3": [50, 75],
    "nodes4": [75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d1 = {
    "nodes2": [50, 75, 100],
    "nodes3": [20, 50, 75, 100],
    "activation": ["relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d2 = {
    "nodes2": [50, 75, 100],
    "nodes3": [20, 50, 75, 100],
    "nodes4": [20, 50, 75, 100],
    "activation": ["relu"],
    "dropout": [0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}


for features in features_list:
    trainX, trainY = generate_train_data_with_fs(4, features)
    run_all_models_FO(4, 10, features)


##
# 6qts
param_grid_lstm1 = {
    "nodes2": [20, 50, 75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm2 = {
    "nodes2": [50, 75],
    "nodes3": [50, 75],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm3 = {
    "nodes2": [20, 50],
    "nodes3": [20, 75, 100],
    "nodes4": [20, 50, 75],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d1 = {
    "nodes2": [20, 50, 75],
    "nodes3": [20, 50],
    "activation": ["relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d2 = {
    "nodes2": [20, 50, 100],
    "nodes3": [20, 50, 75],
    "nodes4": [20, 50, 75],
    "activation": ["relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

for features in features_list:
    trainX, trainY = generate_train_data_with_fs(6, features)
    run_all_models_FO(6, 10, features)


#####
# 8 qts
param_grid_lstm1 = {
    "nodes2": [75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm2 = {
    "nodes2": [50, 75],
    "nodes3": [50, 75],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm3 = {
    "nodes2": [75, 100],
    "nodes3": [50, 75],
    "nodes4": [50, 75],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d1 = {
    "nodes2": [50, 100],
    "nodes3": [20, 50, 75, 100],
    "activation": ["relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d2 = {
    "nodes2": [20, 50, 100],
    "nodes3": [20, 50, 75],
    "nodes4": [20, 50, 75, 100],
    "activation": ["tanh", "relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}


for features in features_list:
    trainX, trainY = generate_train_data_with_fs(8, features)
    run_all_models_FO(8, 10, features)


## 10 qts

param_grid_lstm1 = {
    "nodes2": [50, 75, 124],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm2 = {
    "nodes2": [50, 75],
    "nodes3": [50, 75],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm3 = {
    "nodes2": [75, 100],
    "nodes3": [50, 75],
    "nodes4": [75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d1 = {
    "nodes2": [50, 75, 100],
    "nodes3": [50, 75, 100],
    "activation": ["relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d2 = {
    "nodes2": [20, 50, 75],
    "nodes3": [20, 75, 100],
    "nodes4": [20, 50, 75],
    "activation": ["tanh"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}


for features in features_list:
    trainX, trainY = generate_train_data_with_fs(10, features)
    run_all_models_FO(10, 10, features)

# %% [markdown]
# In this section we deal with testing the best performing models

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
import random
import sklearn as sk
import sklearn.model_selection as skm

from matplotlib import pyplot as plt
import tensorflow as tf

from sklearn.metrics import confusion_matrix
from sklearn import metrics

random.seed(786)
np.random.seed(786)


gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)


from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Sun Feb 26 19:35:39 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    25W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/Colab Notebooks/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %%
def LSTM1(nodes,nodes2, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(model,results)


def LSTM2(nodes,nodes2, nodes3, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(LSTM(nodes3, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(model,results)

def LSTM3(nodes,nodes2, nodes3,nodes4, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(LSTM(nodes3, return_sequences=True))
    model.add(LSTM(nodes4, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,nodes4,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(model,results)

def LSTM1D1(nodes,nodes2, nodes3, activation, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(Dense(nodes3, activation= activation))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,activation, dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(model,results)

def LSTM1D2(nodes,nodes2, nodes3,nodes4,activation, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(Dense(nodes3, activation= activation))
    model.add(Dense(nodes4, activation= activation))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,nodes4,activation,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(model,results)

# %%
def generate_sequence(nqts, nfts, seq_type):
  ntrain =nqts
  ntest = nqts
  feature_cols = nfts + 3


  df = pd.read_csv('full_dataset.csv')
  
  if seq_type == "train": 
    total_qts = 40 - ntrain - ntest
    df = df[df['Time']<(total_qts+1)]
    varimp_file_name = "varimp_{}.csv".format(total_qts)
    print(varimp_file_name)
    varimp = pd.read_csv(varimp_file_name)

  if seq_type == "test":
     total_qts = ntrain + ntest
     df = df[df['Time']>(40- ntrain - ntest)]
     varimp_file_name = "varimp_{}.csv".format(40 - total_qts)
     print(varimp_file_name)
     varimp = pd.read_csv(varimp_file_name)

  if nfts != 123:
    df = df[df.columns.intersection(varimp.iloc[0:feature_cols,0])]
    print("selecting features")
  
  df= df.sort_values(by=['Ticker', 'Time'])
  df = df.reset_index()
  df = df.iloc[:,1:]
  df = df.astype(float)
  scaler = StandardScaler()
  scaler = scaler.fit(df.iloc[:,3:])

  #empty lists
  splitdfY= []
  splitdfX= []

  #append all firms
  x=0
  for i in range(0,127):
      splitdfY.append(df.iloc[x:x+total_qts, :])
      x= x+total_qts
  #
  x=0
  for i in range(0,127):
      df_append = df.iloc[x:x+total_qts, :]
      splitdfX.append(df_append)
      x= x+total_qts
      
  #scale and transform to numpy and set the correct train and test
  trainX = []
  trainY = []
  stride = 1
  y= (((total_qts - ntrain -ntest)/stride)+1)

  for j in range(0,127):
      x=ntest
      for i in range(0,int(y)):
          #trainY.append(pd.DataFrame.to_numpy(splitdf[j].iloc[x:x+ntrain,:1]))
          trainY.append(splitdfY[j].iloc[x:x+ntrain,:1])
          x+= stride

  # 
  for j in range(0,127):
      x=0
      for i in range(0,int(y)):
          df_sc_ap = splitdfX[j].iloc[x:x+ntrain,3:]
          dfX = scaler.transform(df_sc_ap)
          trainX.append(dfX)
          #trainX.append(pd.DataFrame.to_numpy(splitdfX[j].iloc[x:x+ntrain,3:]))
          x+= stride
          
  #finalise the formatting
  trainX = np.array(trainX)
  print('trainX shape == {}.'.format(trainX.shape))

  trainY = np.array(trainY)
  trainY = to_categorical(trainY)
  trainY= trainY[:,:, 1:]
  print('trainY shape == {}.'.format(trainY.shape))

  return trainX, trainY

# %%
def train_models(nqts,nfts,nodes2,nodes3,nodes4,activation ,dropout,optimizer,batchsize,epochs, arch):

  nqts = nqts

  feature_nodes = nfts+1 

  #LSTM1 ------------------------------------------------------------------------------------------------------------------
  #run model and tune
  if arch == 'LLO':
      run = LSTM1(nodes=feature_nodes,\
                        nodes2 = nodes2,\
                        dropout=dropout,\
                        optimizer =optimizer,\
                        batchsize=batchsize, \
                        epochs= epochs)
      

  #LSTM2 ------------------------------------------------------------------------------------------------------------------
  #run model and tune
  if arch == 'LLLO':
      run = LSTM2(nodes=feature_nodes,\
                        nodes2 = nodes2,\
                        nodes3 = nodes3,\
                        dropout=dropout,\
                        optimizer =optimizer,\
                        batchsize=batchsize, \
                        epochs= epochs)

  #LSTM3 ------------------------------------------------------------------------------------------------------------------
  #run model and tune
  if arch == 'LLLLO':
      run = LSTM3(nodes=feature_nodes,\
                        nodes2 = nodes2,\
                        nodes3 = nodes3,\
                        nodes4 = nodes4,\
                        dropout= dropout,\
                        optimizer = optimizer,\
                        batchsize= batchsize, \
                        epochs= epochs)


  #LSTM1D1 ------------------------------------------------------------------------------------------------------------------
  #run model and tune
  if arch == 'LLDO':
      run = LSTM1D1(nodes=feature_nodes,\
                        nodes2 = nodes2,\
                        nodes3 = nodes3,\
                        activation = activation,\
                        dropout=dropout,\
                        optimizer =optimizer,\
                        batchsize=batchsize, \
                        epochs= epochs)
      

  #LSTM1D2 ------------------------------------------------------------------------------------------------------------------
  #run model and tune
  if arch == 'LLDDO':
      run = LSTM1D2(nodes=feature_nodes,\
                        nodes2 = nodes2,\
                        nodes3 = nodes3,\
                        nodes4 = nodes4,\
                        activation = activation,\
                        dropout=dropout,\
                        optimizer =optimizer,\
                        batchsize=batchsize, \
                        epochs= epochs)
      

  return run


def predict_sequences(model,  nqts,nfts, filename):
  testX, testY = generate_sequence(nqts, nfts, "test")

  y_pred = (model.predict(testX))
  print(y_pred.shape)
  y_pred = (y_pred.argmax(axis=2)).reshape(nqts*127)

  y_actu = (testY.argmax(axis=2)).reshape(nqts*127)
  print(confusion_matrix(y_actu,y_pred))
  pd.crosstab(y_actu, y_pred).to_csv("{}.csv".format(filename))
  print(metrics.accuracy_score(y_pred,y_actu))

# %%
trainX, trainY = generate_sequence(2, 10, "train")
model_2_10 = train_models(2,10,50,50,100,"relu",0.2,"Adam",16,10,"LLDDO")
predict_sequences(model_2_10[0],2, 10, "model_2_10_normal")

trainX, trainY = generate_sequence(4, 10, "train")
model_4_10 = train_models(4,10,50,100,50,"relu",0.6,"Adam",16,10,"LLDDO")
predict_sequences(model_4_10[0],4, 10, "model_4_10_normal")

trainX, trainY = generate_sequence(6, 50, "train")
model_6_50 = train_models(6,50,20,50,20,"relu",0.4,"Adam",16,10,"LLDDO")
predict_sequences(model_6_50[0],6, 50, "model_6_50_normal")

trainX, trainY = generate_sequence(8, 25, "train")
model_8_25 = train_models(8,25,100,75,75,"relu",0.6,"Adam",16,10,"LLDDO")
predict_sequences(model_8_25[0],8, 25, "model_8_25_normal")

trainX, trainY = generate_sequence(10, 123, "train")
model_10_123 = train_models(10,123,75,"NA","NA","NA",0.4,"Adam",16,10,"LLO")
predict_sequences(model_10_123[0],10, 123, "model_10_123_normal")
# Out:
# varimp_36.csv
# selecting features
# trainX shape == (4191, 2, 10).
# trainY shape == (4191, 2, 4).
# Epoch 1/10
# 210/210 [==============================] - 6s 10ms/step - loss: 1.0744 - categorical_accuracy: 0.5245 - val_loss: 0.9069 - val_categorical_accuracy: 0.6472
# Epoch 2/10
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8016 - categorical_accuracy: 0.6639 - val_loss: 0.9192 - val_categorical_accuracy: 0.6180
# Epoch 3/10
# 210/210 [==============================] - 1s 7ms/step - loss: 0.7141 - categorical_accuracy: 0.7035 - val_loss: 0.9345 - val_categorical_accuracy: 0.6275
# Epoch 4/10
# 210/210 [==============================] - 1s 7ms/step - loss: 0.6629 - categorical_accuracy: 0.7217 - val_loss: 0.9655 - val_categorical_accuracy: 0.6293
# Epoch 5/10
# 210/210 [==============================] - 1s 7ms/step - loss: 0.6078 - categorical_accuracy: 0.7464 - val_loss: 1.0409 - val_categorical_accuracy: 0.6174
# Epoch 6/10
# 210/210 [==============================] - 1s 7ms/step - loss: 0.5721 - categorical_accuracy: 0.7673 - val_loss: 1.1046 - val_categorical_accuracy: 0.6406
# Epoch 7/10
# 210/210 [==============================] - 1s 7ms/step - loss: 0.5363 - categorical_accuracy: 0.7834 - val_loss: 1.1149 - val_categorical_accuracy: 0.6412
# Epoch 8/10
# 210/210 [==============================] - 1s 7ms/step - loss: 0.5097 - categorical_accuracy: 0.7989 - val_loss: 1.1917 - val_categorical_accuracy: 0.6639
# Epoch 9/10
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4851 - categorical_accuracy: 0.8104 - val_loss: 1.2173 - val_categorical_accuracy: 0.6508
# Epoch 10/10
# 210/210 [==============================] - 2s 7ms/step - loss: 0.4551 - categorical_accuracy: 0.8212 - val_loss: 1.2380 - val_categorical_accuracy: 0.6639
# varimp_36.csv
# selecting features
# trainX shape == (127, 2, 10).
# trainY shape == (127, 2, 4).
# 4/4 [==============================] - 1s 3ms/step
# (127, 2, 4)
# [[43  9  2  0]
#  [17 67 11  3]
#  [ 0 27 36  8]
#  [ 0  7  4 20]]
# 0.6535433070866141
# varimp_32.csv
# selecting features
# trainX shape == (3175, 4, 10).
# trainY shape == (3175, 4, 4).
# Epoch 1/10
# 159/159 [==============================] - 6s 11ms/step - loss: 1.1255 - categorical_accuracy: 0.5125 - val_loss: 1.1717 - val_categorical_accuracy: 0.5213
# Epoch 2/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.8806 - categorical_accuracy: 0.6337 - val_loss: 0.9599 - val_categorical_accuracy: 0.6130
# Epoch 3/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.7703 - categorical_accuracy: 0.6849 - val_loss: 1.0671 - val_categorical_accuracy: 0.6193
# Epoch 4/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.7080 - categorical_accuracy: 0.7064 - val_loss: 1.0804 - val_categorical_accuracy: 0.6157
# Epoch 5/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.6434 - categorical_accuracy: 0.7366 - val_loss: 1.0837 - val_categorical_accuracy: 0.6354
# Epoch 6/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.6115 - categorical_accuracy: 0.7532 - val_loss: 1.1014 - val_categorical_accuracy: 0.6311
# Epoch 7/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.5818 - categorical_accuracy: 0.7679 - val_loss: 1.1399 - val_categorical_accuracy: 0.6319
# Epoch 8/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.5527 - categorical_accuracy: 0.7862 - val_loss: 1.3235 - val_categorical_accuracy: 0.6244
# Epoch 9/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.5463 - categorical_accuracy: 0.7868 - val_loss: 1.4210 - val_categorical_accuracy: 0.6264
# Epoch 10/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.5045 - categorical_accuracy: 0.8037 - val_loss: 1.3842 - val_categorical_accuracy: 0.6291
# varimp_32.csv
# selecting features
# trainX shape == (127, 4, 10).
# trainY shape == (127, 4, 4).
# 4/4 [==============================] - 1s 4ms/step
# (127, 4, 4)
# [[ 88  22   4   0]
#  [ 38 124  15  15]
#  [  7  40  50  42]
#  [  4   9   5  45]]
# 0.6043307086614174
# varimp_28.csv
# selecting features
# trainX shape == (2159, 6, 50).
# trainY shape == (2159, 6, 4).
# Epoch 1/10
# 108/108 [==============================] - 5s 13ms/step - loss: 1.1166 - categorical_accuracy: 0.5517 - val_loss: 1.2123 - val_categorical_accuracy: 0.5529
# Epoch 2/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.6853 - categorical_accuracy: 0.7400 - val_loss: 1.2697 - val_categorical_accuracy: 0.5957
# Epoch 3/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.4706 - categorical_accuracy: 0.8363 - val_loss: 1.4433 - val_categorical_accuracy: 0.6161
# Epoch 4/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.3538 - categorical_accuracy: 0.8836 - val_loss: 1.6137 - val_categorical_accuracy: 0.5995
# Epoch 5/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.2783 - categorical_accuracy: 0.9140 - val_loss: 1.9354 - val_categorical_accuracy: 0.5883
# Epoch 6/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.2343 - categorical_accuracy: 0.9283 - val_loss: 1.9601 - val_categorical_accuracy: 0.6019
# Epoch 7/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1971 - categorical_accuracy: 0.9351 - val_loss: 2.2083 - val_categorical_accuracy: 0.6073
# Epoch 8/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1799 - categorical_accuracy: 0.9439 - val_loss: 2.1281 - val_categorical_accuracy: 0.6273
# Epoch 9/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1687 - categorical_accuracy: 0.9482 - val_loss: 2.2936 - val_categorical_accuracy: 0.6300
# Epoch 10/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1480 - categorical_accuracy: 0.9535 - val_loss: 2.5809 - val_categorical_accuracy: 0.5980
# varimp_28.csv
# selecting features
# trainX shape == (127, 6, 50).
# trainY shape == (127, 6, 4).
# 4/4 [==============================] - 1s 4ms/step
# (127, 6, 4)
# [[135  36   6   0]
#  [ 58 142  53  28]
#  [  8  68 101  30]
#  [  0   9  18  70]]
# 0.5879265091863517
# varimp_24.csv
# selecting features
# trainX shape == (1143, 8, 25).
# trainY shape == (1143, 8, 4).
# Epoch 1/10
# 58/58 [==============================] - 5s 20ms/step - loss: 1.1770 - categorical_accuracy: 0.4873 - val_loss: 1.3696 - val_categorical_accuracy: 0.4973
# Epoch 2/10
# 58/58 [==============================] - 0s 7ms/step - loss: 0.7739 - categorical_accuracy: 0.6928 - val_loss: 1.6133 - val_categorical_accuracy: 0.5186
# Epoch 3/10
# 58/58 [==============================] - 0s 7ms/step - loss: 0.5410 - categorical_accuracy: 0.7953 - val_loss: 1.9472 - val_categorical_accuracy: 0.5218
# Epoch 4/10
# 58/58 [==============================] - 0s 7ms/step - loss: 0.4287 - categorical_accuracy: 0.8481 - val_loss: 1.9599 - val_categorical_accuracy: 0.5126
# Epoch 5/10
# 58/58 [==============================] - 0s 7ms/step - loss: 0.3243 - categorical_accuracy: 0.8946 - val_loss: 2.3820 - val_categorical_accuracy: 0.5011
# Epoch 6/10
# 58/58 [==============================] - 0s 8ms/step - loss: 0.2880 - categorical_accuracy: 0.9024 - val_loss: 2.4218 - val_categorical_accuracy: 0.5246
# Epoch 7/10
# 58/58 [==============================] - 0s 8ms/step - loss: 0.2410 - categorical_accuracy: 0.9252 - val_loss: 2.5096 - val_categorical_accuracy: 0.5393
# Epoch 8/10
# 58/58 [==============================] - 0s 8ms/step - loss: 0.2122 - categorical_accuracy: 0.9394 - val_loss: 2.5137 - val_categorical_accuracy: 0.5262
# Epoch 9/10
# 58/58 [==============================] - 0s 7ms/step - loss: 0.1960 - categorical_accuracy: 0.9406 - val_loss: 2.6749 - val_categorical_accuracy: 0.5262
# Epoch 10/10
# 58/58 [==============================] - 0s 8ms/step - loss: 0.1934 - categorical_accuracy: 0.9412 - val_loss: 2.8167 - val_categorical_accuracy: 0.5349
# varimp_24.csv
# selecting features
# trainX shape == (127, 8, 25).
# trainY shape == (127, 8, 4).
# 4/4 [==============================] - 1s 4ms/step
# (127, 8, 4)
# [[189  53   0   0]
#  [ 92 210  50  20]
#  [ 12  80 133  46]
#  [  0  22  26  83]]
# 0.6053149606299213
# varimp_20.csv
# trainX shape == (127, 10, 121).
# trainY shape == (127, 10, 4).
# Epoch 1/10
# 7/7 [==============================] - 4s 122ms/step - loss: 1.3329 - categorical_accuracy: 0.3228 - val_loss: 1.3172 - val_categorical_accuracy: 0.4962
# Epoch 2/10
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0946 - categorical_accuracy: 0.5663 - val_loss: 1.3065 - val_categorical_accuracy: 0.5269
# Epoch 3/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.9704 - categorical_accuracy: 0.6178 - val_loss: 1.2802 - val_categorical_accuracy: 0.5154
# Epoch 4/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.8620 - categorical_accuracy: 0.6634 - val_loss: 1.2772 - val_categorical_accuracy: 0.4962
# Epoch 5/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7521 - categorical_accuracy: 0.7564 - val_loss: 1.2460 - val_categorical_accuracy: 0.5462
# Epoch 6/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6736 - categorical_accuracy: 0.7861 - val_loss: 1.3021 - val_categorical_accuracy: 0.5538
# Epoch 7/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6010 - categorical_accuracy: 0.8109 - val_loss: 1.3939 - val_categorical_accuracy: 0.5269
# Epoch 8/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5294 - categorical_accuracy: 0.8386 - val_loss: 1.4797 - val_categorical_accuracy: 0.5346
# Epoch 9/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4628 - categorical_accuracy: 0.8703 - val_loss: 1.5331 - val_categorical_accuracy: 0.5000
# Epoch 10/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4246 - categorical_accuracy: 0.8851 - val_loss: 1.6965 - val_categorical_accuracy: 0.5038
# varimp_20.csv
# trainX shape == (127, 10, 121).
# trainY shape == (127, 10, 4).
# 4/4 [==============================] - 1s 3ms/step
# (127, 10, 4)
# [[244  42   5  17]
#  [166 242  11  44]
#  [ 38 146  94  59]
#  [  0  53  26  83]]
# 0.5220472440944882

# %%
def plot_learning_curves(run):
  history = run[0].history
  plt.plot([(1-z)*100 for z in history.history['categorical_accuracy']])
  plt.plot([(1-z)*100 for z in history.history['val_categorical_accuracy']])
  #plt.title('model 1 train and validation accuracy')
  plt.ylabel('Misclassification rate in %')
  plt.xlabel('Epoch')
  #plt.legend(['Training', 'Validation'], loc='upper left')
  #plt.legend('')
  plt.show()


trainX, trainY = generate_sequence(2, 10, "train")
model_2_10 = train_models(2,10,50,50,100,"relu",0.2,"Adam",16,50,"LLDDO")
plot_learning_curves(model_2_10)
# Out:
# varimp_36.csv
# selecting features
# trainX shape == (4191, 2, 10).
# trainY shape == (4191, 2, 4).
# Epoch 1/50
# 210/210 [==============================] - 6s 10ms/step - loss: 1.0664 - categorical_accuracy: 0.5371 - val_loss: 0.9821 - val_categorical_accuracy: 0.6359
# Epoch 2/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8270 - categorical_accuracy: 0.6496 - val_loss: 0.9312 - val_categorical_accuracy: 0.6240
# Epoch 3/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.7534 - categorical_accuracy: 0.6823 - val_loss: 0.9382 - val_categorical_accuracy: 0.6073
# Epoch 4/50
# 210/210 [==============================] - 2s 7ms/step - loss: 0.7080 - categorical_accuracy: 0.6957 - val_loss: 0.9664 - val_categorical_accuracy: 0.6281
# Epoch 5/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.6557 - categorical_accuracy: 0.7170 - val_loss: 1.0520 - val_categorical_accuracy: 0.6371
# Epoch 6/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.6152 - categorical_accuracy: 0.7467 - val_loss: 1.0067 - val_categorical_accuracy: 0.6275
# Epoch 7/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.5769 - categorical_accuracy: 0.7645 - val_loss: 1.1219 - val_categorical_accuracy: 0.6103
# Epoch 8/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.5478 - categorical_accuracy: 0.7785 - val_loss: 1.1607 - val_categorical_accuracy: 0.6156
# Epoch 9/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.5196 - categorical_accuracy: 0.7915 - val_loss: 1.1523 - val_categorical_accuracy: 0.6186
# Epoch 10/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.5030 - categorical_accuracy: 0.8049 - val_loss: 1.1351 - val_categorical_accuracy: 0.6246
# Epoch 11/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4780 - categorical_accuracy: 0.8103 - val_loss: 1.1361 - val_categorical_accuracy: 0.6311
# Epoch 12/50
# 210/210 [==============================] - 2s 7ms/step - loss: 0.4535 - categorical_accuracy: 0.8183 - val_loss: 1.2753 - val_categorical_accuracy: 0.6061
# Epoch 13/50
# 210/210 [==============================] - 2s 7ms/step - loss: 0.4398 - categorical_accuracy: 0.8280 - val_loss: 1.2395 - val_categorical_accuracy: 0.6156
# Epoch 14/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4265 - categorical_accuracy: 0.8350 - val_loss: 1.2805 - val_categorical_accuracy: 0.6400
# Epoch 15/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4129 - categorical_accuracy: 0.8365 - val_loss: 1.2959 - val_categorical_accuracy: 0.6389
# Epoch 16/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.4083 - categorical_accuracy: 0.8392 - val_loss: 1.4035 - val_categorical_accuracy: 0.6216
# Epoch 17/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.3898 - categorical_accuracy: 0.8514 - val_loss: 1.3568 - val_categorical_accuracy: 0.6448
# Epoch 18/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.3788 - categorical_accuracy: 0.8535 - val_loss: 1.5195 - val_categorical_accuracy: 0.6246
# Epoch 19/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.3646 - categorical_accuracy: 0.8586 - val_loss: 1.5369 - val_categorical_accuracy: 0.6210
# Epoch 20/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.3590 - categorical_accuracy: 0.8599 - val_loss: 1.4659 - val_categorical_accuracy: 0.6395
# Epoch 21/50
# 210/210 [==============================] - 2s 8ms/step - loss: 0.3413 - categorical_accuracy: 0.8690 - val_loss: 1.5423 - val_categorical_accuracy: 0.6299
# Epoch 22/50
# 210/210 [==============================] - 2s 8ms/step - loss: 0.3445 - categorical_accuracy: 0.8644 - val_loss: 1.6128 - val_categorical_accuracy: 0.6234
# Epoch 23/50
# 210/210 [==============================] - 2s 8ms/step - loss: 0.3306 - categorical_accuracy: 0.8684 - val_loss: 1.7069 - val_categorical_accuracy: 0.6263
# Epoch 24/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.3233 - categorical_accuracy: 0.8756 - val_loss: 1.6897 - val_categorical_accuracy: 0.6359
# Epoch 25/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.3169 - categorical_accuracy: 0.8735 - val_loss: 1.7880 - val_categorical_accuracy: 0.6377
# Epoch 26/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.3035 - categorical_accuracy: 0.8848 - val_loss: 1.8205 - val_categorical_accuracy: 0.6281
# Epoch 27/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.3001 - categorical_accuracy: 0.8826 - val_loss: 1.6981 - val_categorical_accuracy: 0.6591
# Epoch 28/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2958 - categorical_accuracy: 0.8862 - val_loss: 1.8499 - val_categorical_accuracy: 0.6168
# Epoch 29/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2934 - categorical_accuracy: 0.8865 - val_loss: 1.8434 - val_categorical_accuracy: 0.6359
# Epoch 30/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2771 - categorical_accuracy: 0.8950 - val_loss: 1.9996 - val_categorical_accuracy: 0.6240
# Epoch 31/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2783 - categorical_accuracy: 0.8948 - val_loss: 1.9890 - val_categorical_accuracy: 0.6263
# Epoch 32/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2628 - categorical_accuracy: 0.8977 - val_loss: 2.0853 - val_categorical_accuracy: 0.6198
# Epoch 33/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2651 - categorical_accuracy: 0.8984 - val_loss: 2.0084 - val_categorical_accuracy: 0.6365
# Epoch 34/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2507 - categorical_accuracy: 0.9041 - val_loss: 2.1233 - val_categorical_accuracy: 0.6222
# Epoch 35/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2601 - categorical_accuracy: 0.8986 - val_loss: 2.1663 - val_categorical_accuracy: 0.6222
# Epoch 36/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2468 - categorical_accuracy: 0.9086 - val_loss: 2.1601 - val_categorical_accuracy: 0.6341
# Epoch 37/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2460 - categorical_accuracy: 0.9057 - val_loss: 2.3333 - val_categorical_accuracy: 0.6395
# Epoch 38/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2424 - categorical_accuracy: 0.9069 - val_loss: 2.2949 - val_categorical_accuracy: 0.6335
# Epoch 39/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2374 - categorical_accuracy: 0.9039 - val_loss: 2.3706 - val_categorical_accuracy: 0.6240
# Epoch 40/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2333 - categorical_accuracy: 0.9115 - val_loss: 2.1646 - val_categorical_accuracy: 0.6365
# Epoch 41/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2244 - categorical_accuracy: 0.9150 - val_loss: 2.3048 - val_categorical_accuracy: 0.6228
# Epoch 42/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2211 - categorical_accuracy: 0.9139 - val_loss: 2.4101 - val_categorical_accuracy: 0.6371
# Epoch 43/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2129 - categorical_accuracy: 0.9154 - val_loss: 2.5295 - val_categorical_accuracy: 0.6418
# Epoch 44/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2181 - categorical_accuracy: 0.9132 - val_loss: 2.5105 - val_categorical_accuracy: 0.6287
# Epoch 45/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.2136 - categorical_accuracy: 0.9196 - val_loss: 2.5141 - val_categorical_accuracy: 0.6406
# Epoch 46/50
# 210/210 [==============================] - 2s 7ms/step - loss: 0.2028 - categorical_accuracy: 0.9227 - val_loss: 2.5569 - val_categorical_accuracy: 0.6365
# Epoch 47/50
# 210/210 [==============================] - 2s 7ms/step - loss: 0.1981 - categorical_accuracy: 0.9215 - val_loss: 2.5712 - val_categorical_accuracy: 0.6406
# Epoch 48/50
# 210/210 [==============================] - 2s 7ms/step - loss: 0.2009 - categorical_accuracy: 0.9202 - val_loss: 2.7357 - val_categorical_accuracy: 0.6400
# Epoch 49/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.1983 - categorical_accuracy: 0.9218 - val_loss: 2.5343 - val_categorical_accuracy: 0.6472
# Epoch 50/50
# 210/210 [==============================] - 1s 7ms/step - loss: 0.1890 - categorical_accuracy: 0.9251 - val_loss: 2.7005 - val_categorical_accuracy: 0.6311
