# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout
import pandas as pd
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
import random
import sklearn as sk
import sklearn.model_selection as skm

random.seed(786)
np.random.seed(786)


gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)


from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Sun Feb 26 21:02:09 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    25W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/Colab Notebooks/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %%
from keras import backend as K
 
def ignore_class_accuracy(to_ignore=0):
    def ignore_accuracy(y_true, y_pred):
        y_true_class = K.argmax(y_true, axis=-1)
        y_pred_class = K.argmax(y_pred, axis=-1)
 
        ignore_mask = K.cast(K.not_equal(y_pred_class, to_ignore), 'int32')
        matches = K.cast(K.equal(y_true_class, y_pred_class), 'int32') * ignore_mask
        accuracy = K.sum(matches) / K.maximum(K.sum(ignore_mask), 1)
        return accuracy
    return ignore_accuracy

# %%
def LSTM1(nodes,nodes2, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)


def LSTM2(nodes,nodes2, nodes3, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(LSTM(nodes3, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

def LSTM3(nodes,nodes2, nodes3,nodes4, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(LSTM(nodes3, return_sequences=True))
    model.add(LSTM(nodes4, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,nodes4,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

def LSTM1D1(nodes,nodes2, nodes3, activation, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(Dense(nodes3, activation= activation))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,activation, dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

def LSTM1D2(nodes,nodes2, nodes3,nodes4,activation, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(Dense(nodes3, activation= activation))
    model.add(Dense(nodes4, activation= activation))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,nodes4,activation,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(results)

# %%
# dropout at the end is here 
# https://www.researchgate.net/publication/308849574_Where_to_apply_dropout_in_recurrent_neural_networks_for_handwriting_recognition

# %%
def generate_shifted_sequence(ntr, nts, nfts, seq_type):
    ntrain = ntr
    ntest = nts
    feature_cols = nfts + 3

    df = pd.read_csv("full_dataset.csv")

    if seq_type == "train":
        total_qts = 40 - ntrain - ntest
        df = df[df["Time"] < (total_qts + 1)]
        varimp_file_name = "varimp_{}.csv".format(total_qts)
        print(varimp_file_name)
        varimp = pd.read_csv(varimp_file_name)

    if seq_type == "test":
        total_qts = ntrain + ntest
        df = df[df["Time"] > (40 - ntrain - ntest)]
        varimp_file_name = "varimp_{}.csv".format(40 - total_qts)
        print(varimp_file_name)
        varimp = pd.read_csv(varimp_file_name)

    if nfts != 123:
        df = df[df.columns.intersection(varimp.iloc[0:feature_cols, 0])]
        print("selecting features")

    df = df.sort_values(by=["Ticker", "Time"])
    df = df.reset_index()
    df = df.iloc[:, 1:]
    df = df.astype(float)
    scaler = StandardScaler()
    scaler = scaler.fit(df.iloc[:, 3:])

    # empty lists
    splitdfY = []
    splitdfX = []

    # append all firms
    x = 0
    for i in range(0, 127):
        splitdfY.append(df.iloc[x : x + total_qts, :])
        x = x + total_qts
    #
    x = 0
    for i in range(0, 127):
        df_append = df.iloc[x : x + total_qts, :]
        splitdfX.append(df_append)
        x = x + total_qts

    # scale and transform to numpy and set the correct train and test
    trainX = []
    trainY = []
    stride = 1
    y = ((total_qts - ntrain - ntest) / stride) + 1

    for j in range(0, 127):
        x = ntest  # this is a distinct difference
        for i in range(0, int(y)):
            # trainY.append(pd.DataFrame.to_numpy(splitdf[j].iloc[x:x+ntrain,:1]))
            trainY.append(splitdfY[j].iloc[x : x + ntrain, :1])
            x += stride

    #
    for j in range(0, 127):
        x = 0
        for i in range(0, int(y)):
            df_sc_ap = splitdfX[j].iloc[x : x + ntrain, 3:]
            dfX = scaler.transform(df_sc_ap)
            trainX.append(dfX)
            # trainX.append(pd.DataFrame.to_numpy(splitdfX[j].iloc[x:x+ntrain,3:]))
            x += stride

    # finalise the formatting
    trainX = np.array(trainX)
    print("trainX shape == {}.".format(trainX.shape))

    trainY = np.array(trainY)
    trainY = to_categorical(trainY)
    trainY = trainY[:, :, 1:]
    print("trainY shape == {}.".format(trainY.shape))

    # print('padding Y')
    # trainY= np.pad(trainY, ((0,0),(ntrain-ntest,0),(0,0)), "constant")
    # print('trainY shape == {}.'.format(trainY.shape))

    return trainX, trainY

# %%
def run_all_models_FO(nqts, epochs):
  nqts = nqts
  

  #LSTM1 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']

  grid1 = skm.ParameterGrid(param_grid_lstm1)
  results_df = pd.DataFrame(columns= columns)
  run_no =1
  #run model and tune
  for params in grid1:
      run = LSTM1(nodes=124,\
                        nodes2 = params['nodes2'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no, "of LSTM1")
  results_df.to_csv("LSTM1_FO_{}_2ts_sh.csv".format(nqts))

  #LSTM2 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  run_no =1

  grid2 = skm.ParameterGrid(param_grid_lstm2)

  #run model and tune
  for params in grid2:
      run = LSTM2(nodes=124,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no , "of LSTM2")
  results_df.to_csv("LSTM2_FO_{}_2ts_sh.csv".format(nqts))

  #LSTM3 ------------------------------------------------------------------------------------------------------------------

  #initialize the empty results dataframe
  columns = ['nodes','nodes2','nodes3','nodes4','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  run_no =1

  grid3 = skm.ParameterGrid(param_grid_lstm3)
  #run model and tune
  for params in grid3:
      run = LSTM3(nodes=124,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        nodes4 = params['nodes4'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)    
      run_no +=1
      print(run_no, "of LSTM3")
  results_df.to_csv("LSTM3_FO_{}_2ts_sh.csv".format(nqts))


  #LSTM1D1 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','activation','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  #initialize loading variables batch size of 64
  run_no =1
  grid4 = skm.ParameterGrid(param_grid_lstm1d1)
  #run model and tune
  for params in grid4:
      run = LSTM1D1(nodes=124,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        activation = params['activation'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no, "of LSTM1D1")
  results_df.to_csv("LSTM1D1_FO_{}_2ts_sh.csv".format(nqts))


  #LSTM1D2 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','nodes4','activation','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  grid5 = skm.ParameterGrid(param_grid_lstm1d2)
  #initialize loading variables
  run_no =1
  #run model and tune
  for params in grid5:
      run = LSTM1D2(nodes=124,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        nodes4 = params['nodes4'],\
                        activation = params['activation'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      
      run_no +=1
      print(run_no, "of LSTM1D2")
  results_df.to_csv("LSTM1D2_FO_{}_2ts_sh.csv".format(nqts))

# %%
param_grid_lstm1 = {'nodes2': [20, 50, 75, 100, 124],\
              'dropout' : [0.4, 0.6],\
              'optimizer' : ['Adam'],\
              'batchsize' : [16]}

param_grid_lstm2 = {'nodes2': [20, 50, 75, 100, 124],\
              'nodes3': [20, 50, 75, 100, 124],\
              'dropout' : [0.4, 0.6],\
              'optimizer' : ['Adam'],\
              'batchsize' : [16]}

param_grid_lstm3 = {'nodes2': [20, 50, 75, 100],\
              'nodes3': [20, 50, 75, 100],\
              'nodes4': [20, 50, 75, 100],\
              'dropout' : [0.4, 0.6],\
              'optimizer' : ['Adam'],\
              'batchsize' : [16]}

param_grid_lstm1d1 = {'nodes2': [20, 50, 75, 100],\
              'nodes3': [20, 50, 75, 100],\
              'activation': ['tanh', 'relu'],\
              'dropout' : [0.4, 0.6],\
              'optimizer' : ['Adam'],\
              'batchsize' : [16]}

param_grid_lstm1d2 = {'nodes2': [20, 50, 75, 100],\
              'nodes3': [20, 50, 75, 100],\
              'nodes4': [20, 50, 75, 100],\
              'activation': ['tanh', 'relu'],\
              'dropout' : [0.4, 0.6],\
              'optimizer' : ['Adam'],\
              'batchsize' : [16]}

# %%
trainX, trainY = generate_shifted_sequence(4, 2, 123, "train")
run_all_models_FO(4,10)
print("done with 4")

trainX, trainY = generate_shifted_sequence(6, 2, 123, "train")
run_all_models_FO(6,10)
print("done with 6")

trainX, trainY = generate_shifted_sequence(8, 2, 123, "train")
run_all_models_FO(8,10)
print("done with 8")

trainX, trainY = generate_shifted_sequence(10, 2, 123, "train")
run_all_models_FO(10, 10)
print("done with 10")

# %%
#this section is for feature selction

# %%
def run_all_models_FO(nqts, epochs, nfts):
  nqts = nqts

  feature_nodes = nfts+1 
  

  #LSTM1 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']

  grid1 = skm.ParameterGrid(param_grid_lstm1)
  results_df = pd.DataFrame(columns= columns)
  run_no =1
  #run model and tune
  for params in grid1:
      run = LSTM1(nodes=feature_nodes,\
                        nodes2 = params['nodes2'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no, "of LSTM1")
  results_df.to_csv("LSTM1_FO_{q}_{f}_2ts.csv".format(q = nqts, f= nfts))

  #LSTM2 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  run_no =1

  grid2 = skm.ParameterGrid(param_grid_lstm2)

  #run model and tune
  for params in grid2:
      run = LSTM2(nodes=feature_nodes,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no , "of LSTM2")
  results_df.to_csv("LSTM2_FO_{q}_{f}_2ts.csv".format(q = nqts, f= nfts))

  #LSTM3 ------------------------------------------------------------------------------------------------------------------

  #initialize the empty results dataframe
  columns = ['nodes','nodes2','nodes3','nodes4','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  run_no =1

  grid3 = skm.ParameterGrid(param_grid_lstm3)
  #run model and tune
  for params in grid3:
      run = LSTM3(nodes=feature_nodes,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        nodes4 = params['nodes4'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)    
      run_no +=1
      print(run_no, "of LSTM3")
  results_df.to_csv("LSTM3_FO_{q}_{f}_2ts.csv".format(q = nqts, f= nfts))


  #LSTM1D1 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','activation','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  #initialize loading variables batch size of 64
  run_no =1
  grid4 = skm.ParameterGrid(param_grid_lstm1d1)
  #run model and tune
  for params in grid4:
      run = LSTM1D1(nodes=feature_nodes,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        activation = params['activation'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      run_no +=1
      print(run_no, "of LSTM1D1")
  results_df.to_csv("LSTM1D1_FO_{q}_{f}_2ts.csv".format(q = nqts, f= nfts))


  #LSTM1D2 ------------------------------------------------------------------------------------------------------------------
  columns = ['nodes','nodes2','nodes3','nodes4','activation','dropout','optimizer','batchsize','epochs','max_train', 'test_pct']
  results_df = pd.DataFrame(columns= columns)
  grid5 = skm.ParameterGrid(param_grid_lstm1d2)
  #initialize loading variables
  run_no =1
  #run model and tune
  for params in grid5:
      run = LSTM1D2(nodes=feature_nodes,\
                        nodes2 = params['nodes2'],\
                        nodes3 = params['nodes3'],\
                        nodes4 = params['nodes4'],\
                        activation = params['activation'],\
                        dropout=params['dropout'],\
                        optimizer =params['optimizer'],\
                        batchsize=params['batchsize'], \
                        epochs= epochs)
      
      run_s = pd.Series(run, index = columns)
      
      results_df = results_df.append(run_s, ignore_index = True)
      
      run_no +=1
      print(run_no, "of LSTM1D2")
  results_df.to_csv("LSTM1D2_FO_{q}_{f}_2ts.csv".format(q = nqts, f= nfts))

# %%
features_list = [5,10,25,50,75]

# 4
param_grid_lstm1 = {
    "nodes2": [50, 75, 100],
    "dropout": [0.4],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm2 = {
    "nodes2": [50, 124],
    "nodes3": [50, 75],
    "dropout": [0.4],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm3 = {
    "nodes2": [75, 100],
    "nodes3": [50, 75],
    "nodes4": [75, 100],
    "dropout": [0.4],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d1 = {
    "nodes2": [50, 75],
    "nodes3": [20, 50, 75],
    "activation": ["tanh"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d2 = {
    "nodes2": [20, 50, 100],
    "nodes3": [20, 75, 100],
    "nodes4": [20, 50, 75, 100],
    "activation": ["tanh", "relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

for features in features_list:
    trainX, trainY = generate_shifted_sequence(4, 2, features, "train")
    run_all_models_FO(4, 10, features)
print("done with 4")


# ________________________________________________________________6

param_grid_lstm1 = {
    "nodes2": [20, 50],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm2 = {
    "nodes2": [20, 50, 75],
    "nodes3": [20, 50, 75],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm3 = {
    "nodes2": [50, 75],
    "nodes3": [20, 50, 75],
    "nodes4": [50, 75],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d1 = {
    "nodes2": [20, 75, 100],
    "nodes3": [20, 50, 75],
    "activation": ["tanh", "relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d2 = {
    "nodes2": [20, 50, 75, 100],
    "nodes3": [20, 50, 75, 100],
    "nodes4": [20, 50, 75],
    "activation": ["relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}


for features in features_list:
    trainX, trainY = generate_shifted_sequence(6, 2, features, "train")
    run_all_models_FO(6, 10, features)
print("done with 6")


# ________________________________________________________________8
param_grid_lstm1 = {
    "nodes2": [75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm2 = {
    "nodes2": [75, 100],
    "nodes3": [20, 50],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm3 = {
    "nodes2": [20, 50, 100],
    "nodes3": [50, 75],
    "nodes4": [20, 50, 75],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d1 = {
    "nodes2": [20, 50, 75],
    "nodes3": [20, 50, 75],
    "activation": ["relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d2 = {
    "nodes2": [50, 75, 100],
    "nodes3": [20, 50],
    "nodes4": [20, 50, 75, 100],
    "activation": ["tanh", "relu"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}


for features in features_list:
    trainX, trainY = generate_shifted_sequence(8, 2, features, "train")
    run_all_models_FO(8, 10, features)
print("done with 8")


# ________________________________________________________________10


param_grid_lstm1 = {
    "nodes2": [75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm2 = {
    "nodes2": [75, 100],
    "nodes3": [20, 50, 75],
    "dropout": [0.4],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm3 = {
    "nodes2": [50, 75],
    "nodes3": [20, 50],
    "nodes4": [75, 100],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d1 = {
    "nodes2": [50, 75, 100],
    "nodes3": [20, 50, 75],
    "activation": ["tanh"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}

param_grid_lstm1d2 = {
    "nodes2": [20, 50, 75],
    "nodes3": [20, 50, 75],
    "nodes4": [20, 50, 75, 100],
    "activation": ["relu", "tanh"],
    "dropout": [0.4, 0.6],
    "optimizer": ["Adam"],
    "batchsize": [16],
}


for features in features_list:
    trainX, trainY = generate_shifted_sequence(10, 2, features, "train")
    run_all_models_FO(10, 10, features)
print("done with 10")

# %%
# testing begins here

# %%
def LSTM1(nodes,nodes2, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(model,results)


def LSTM2(nodes,nodes2, nodes3, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(LSTM(nodes3, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(model,results)

def LSTM3(nodes,nodes2, nodes3,nodes4, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(LSTM(nodes3, return_sequences=True))
    model.add(LSTM(nodes4, return_sequences=True))
    #model.add(Dense(120, activation= 'tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,nodes4,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(model,results)

def LSTM1D1(nodes,nodes2, nodes3, activation, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(Dense(nodes3, activation= activation))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,activation, dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(model,results)

def LSTM1D2(nodes,nodes2, nodes3,nodes4,activation, dropout,optimizer,batchsize,epochs):
    model = Sequential()
    model.add(LSTM(nodes, input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
    model.add(LSTM(nodes2, return_sequences=True))
    model.add(Dense(nodes3, activation= activation))
    model.add(Dense(nodes4, activation= activation))
    model.add(Dropout(dropout))
    model.add(Dense(4, activation= 'softmax'))

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics='categorical_accuracy')
    #model.summary()

    # fit model
    history = model.fit(trainX, trainY, epochs=epochs, batch_size=batchsize, validation_split=0.2, verbose=1)
    max_train_pct = round((np.amax(history.history['categorical_accuracy'])*100),2)
    max_test_pct = round((np.amax(history.history['val_categorical_accuracy'])*100),2)
    
    results = [nodes,nodes2,nodes3,nodes4,activation,dropout,optimizer,batchsize,epochs,max_train_pct, max_test_pct]
    
    return(model,results)


def train_models(nqts,nfts,nodes2,nodes3,nodes4,activation ,dropout,optimizer,batchsize,epochs, arch):

  nqts = nqts

  feature_nodes = nfts+1 

  #LSTM1 ------------------------------------------------------------------------------------------------------------------
  #run model and tune
  if arch == 'LLO':
      run = LSTM1(nodes=feature_nodes,\
                        nodes2 = nodes2,\
                        dropout=dropout,\
                        optimizer =optimizer,\
                        batchsize=batchsize, \
                        epochs= epochs)
      

  #LSTM2 ------------------------------------------------------------------------------------------------------------------
  #run model and tune
  if arch == 'LLLO':
      run = LSTM2(nodes=feature_nodes,\
                        nodes2 = nodes2,\
                        nodes3 = nodes3,\
                        dropout=dropout,\
                        optimizer =optimizer,\
                        batchsize=batchsize, \
                        epochs= epochs)

  #LSTM3 ------------------------------------------------------------------------------------------------------------------
  #run model and tune
  if arch == 'LLLLO':
      run = LSTM3(nodes=feature_nodes,\
                        nodes2 = nodes2,\
                        nodes3 = nodes3,\
                        nodes4 = nodes4,\
                        dropout= dropout,\
                        optimizer = optimizer,\
                        batchsize= batchsize, \
                        epochs= epochs)


  #LSTM1D1 ------------------------------------------------------------------------------------------------------------------
  #run model and tune
  if arch == 'LLDO':
      run = LSTM1D1(nodes=feature_nodes,\
                        nodes2 = nodes2,\
                        nodes3 = nodes3,\
                        activation = activation,\
                        dropout=dropout,\
                        optimizer =optimizer,\
                        batchsize=batchsize, \
                        epochs= epochs)
      

  #LSTM1D2 ------------------------------------------------------------------------------------------------------------------
  #run model and tune
  if arch == 'LLDDO':
      run = LSTM1D2(nodes=feature_nodes,\
                        nodes2 = nodes2,\
                        nodes3 = nodes3,\
                        nodes4 = nodes4,\
                        activation = activation,\
                        dropout=dropout,\
                        optimizer =optimizer,\
                        batchsize=batchsize, \
                        epochs= epochs)
      

  return run

# %%
from sklearn.metrics import confusion_matrix
from sklearn import metrics

from matplotlib import pyplot as plt

def predict_sequences(model, nqts,nfts, filename):
  testX, testY = generate_shifted_sequence(nqts,2, nfts, "test")

  y_pred = (model.predict(testX))
  y_pred= (y_pred[:,nqts-2:nqts,:])
  print(y_pred.shape)

  y_pred = (y_pred.argmax(axis=2)).reshape(2*127)

  testY = testY[:,nqts-2:nqts,: ]
  y_actu = (testY.argmax(axis=2)).reshape(2*127)
  print(confusion_matrix(y_actu,y_pred))
  pd.crosstab(y_actu, y_pred).to_csv("{}.csv".format(filename))
  print(metrics.accuracy_score(y_pred,y_actu))

# %%
trainX, trainY = generate_shifted_sequence(4,2,10, "train")
model_4_10_sh = train_models(4,10,50,75,20,"tanh",0.4,"Adam",16,10,"LLDDO")
predict_sequences(model_4_10_sh[0], 4,10, "model_4_10_sh")

trainX, trainY = generate_shifted_sequence(6,2,10, "train")
model_6_10_sh = train_models(6,10,100,100,50,"relu",0.4,"Adam",16,10,"LLDDO")
predict_sequences(model_6_10_sh[0], 6,10, "model_6_10_sh")

trainX, trainY = generate_shifted_sequence(8,2,25, "train")
model_8_25_sh = train_models(8,25,100,20,20,"tanh",0.6,"Adam",16,10,"LLDDO")
predict_sequences(model_8_25_sh[0], 8,25, "model_8_25_sh")

trainX, trainY = generate_shifted_sequence(10,2,123, "train")
model_10_123_sh = train_models(10,123,20,20,100,"relu",0.4,"Adam",16,10,"LLDDO")
predict_sequences(model_10_123_sh[0], 10,123, "model_10_123_sh")
# Out:
# varimp_34.csv
# selecting features
# trainX shape == (3683, 4, 10).
# trainY shape == (3683, 4, 4).
# Epoch 1/10
# 185/185 [==============================] - 6s 11ms/step - loss: 1.0680 - categorical_accuracy: 0.5418 - val_loss: 0.9999 - val_categorical_accuracy: 0.6252
# Epoch 2/10
# 185/185 [==============================] - 1s 7ms/step - loss: 0.8406 - categorical_accuracy: 0.6484 - val_loss: 0.9621 - val_categorical_accuracy: 0.6252
# Epoch 3/10
# 185/185 [==============================] - 1s 7ms/step - loss: 0.7404 - categorical_accuracy: 0.7001 - val_loss: 0.9554 - val_categorical_accuracy: 0.6265
# Epoch 4/10
# 185/185 [==============================] - 1s 7ms/step - loss: 0.6815 - categorical_accuracy: 0.7270 - val_loss: 0.9874 - val_categorical_accuracy: 0.6119
# Epoch 5/10
# 185/185 [==============================] - 1s 7ms/step - loss: 0.6292 - categorical_accuracy: 0.7503 - val_loss: 1.0699 - val_categorical_accuracy: 0.6150
# Epoch 6/10
# 185/185 [==============================] - 1s 7ms/step - loss: 0.5919 - categorical_accuracy: 0.7671 - val_loss: 1.0971 - val_categorical_accuracy: 0.6486
# Epoch 7/10
# 185/185 [==============================] - 1s 7ms/step - loss: 0.5537 - categorical_accuracy: 0.7883 - val_loss: 1.1296 - val_categorical_accuracy: 0.6465
# Epoch 8/10
# 185/185 [==============================] - 1s 7ms/step - loss: 0.5338 - categorical_accuracy: 0.7987 - val_loss: 1.1064 - val_categorical_accuracy: 0.6486
# Epoch 9/10
# 185/185 [==============================] - 1s 7ms/step - loss: 0.5092 - categorical_accuracy: 0.8083 - val_loss: 1.1736 - val_categorical_accuracy: 0.6153
# Epoch 10/10
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4912 - categorical_accuracy: 0.8136 - val_loss: 1.1687 - val_categorical_accuracy: 0.6364
# varimp_34.csv
# selecting features
# trainX shape == (127, 4, 10).
# trainY shape == (127, 4, 4).
# 4/4 [==============================] - 1s 4ms/step
# (127, 2, 4)
# [[47  5  2  0]
#  [22 65  7  4]
#  [ 3 22 39  7]
#  [ 2  2  7 20]]
# 0.6732283464566929
# varimp_32.csv
# selecting features
# trainX shape == (3175, 6, 10).
# trainY shape == (3175, 6, 4).
# Epoch 1/10
# 159/159 [==============================] - 6s 12ms/step - loss: 1.1136 - categorical_accuracy: 0.5341 - val_loss: 1.0604 - val_categorical_accuracy: 0.5900
# Epoch 2/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.8329 - categorical_accuracy: 0.6510 - val_loss: 1.0301 - val_categorical_accuracy: 0.6297
# Epoch 3/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.7015 - categorical_accuracy: 0.7191 - val_loss: 1.0536 - val_categorical_accuracy: 0.6223
# Epoch 4/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.6221 - categorical_accuracy: 0.7519 - val_loss: 1.0924 - val_categorical_accuracy: 0.6444
# Epoch 5/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.5641 - categorical_accuracy: 0.7788 - val_loss: 1.1793 - val_categorical_accuracy: 0.6328
# Epoch 6/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.5152 - categorical_accuracy: 0.7979 - val_loss: 1.2106 - val_categorical_accuracy: 0.6591
# Epoch 7/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.4691 - categorical_accuracy: 0.8209 - val_loss: 1.2976 - val_categorical_accuracy: 0.6478
# Epoch 8/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.4237 - categorical_accuracy: 0.8384 - val_loss: 1.4006 - val_categorical_accuracy: 0.6533
# Epoch 9/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.3870 - categorical_accuracy: 0.8516 - val_loss: 1.5550 - val_categorical_accuracy: 0.6559
# Epoch 10/10
# 159/159 [==============================] - 1s 7ms/step - loss: 0.3593 - categorical_accuracy: 0.8610 - val_loss: 1.6591 - val_categorical_accuracy: 0.6381
# varimp_32.csv
# selecting features
# trainX shape == (127, 6, 10).
# trainY shape == (127, 6, 4).
# 4/4 [==============================] - 1s 4ms/step
# (127, 2, 4)
# [[44  8  2  0]
#  [24 52 18  4]
#  [ 1 19 30 21]
#  [ 0  6  2 23]]
# 0.5866141732283464
# varimp_30.csv
# selecting features
# trainX shape == (2667, 8, 25).
# trainY shape == (2667, 8, 4).
# Epoch 1/10
# 134/134 [==============================] - 6s 13ms/step - loss: 0.9660 - categorical_accuracy: 0.6076 - val_loss: 1.0173 - val_categorical_accuracy: 0.5824
# Epoch 2/10
# 134/134 [==============================] - 1s 8ms/step - loss: 0.6127 - categorical_accuracy: 0.7763 - val_loss: 1.1285 - val_categorical_accuracy: 0.5669
# Epoch 3/10
# 134/134 [==============================] - 1s 8ms/step - loss: 0.4571 - categorical_accuracy: 0.8410 - val_loss: 1.3798 - val_categorical_accuracy: 0.5787
# Epoch 4/10
# 134/134 [==============================] - 1s 7ms/step - loss: 0.3658 - categorical_accuracy: 0.8754 - val_loss: 1.5601 - val_categorical_accuracy: 0.5531
# Epoch 5/10
# 134/134 [==============================] - 1s 7ms/step - loss: 0.3159 - categorical_accuracy: 0.8946 - val_loss: 1.6319 - val_categorical_accuracy: 0.5815
# Epoch 6/10
# 134/134 [==============================] - 1s 7ms/step - loss: 0.2781 - categorical_accuracy: 0.9136 - val_loss: 1.8323 - val_categorical_accuracy: 0.5868
# Epoch 7/10
# 134/134 [==============================] - 1s 7ms/step - loss: 0.2424 - categorical_accuracy: 0.9214 - val_loss: 2.0264 - val_categorical_accuracy: 0.5637
# Epoch 8/10
# 134/134 [==============================] - 1s 7ms/step - loss: 0.2022 - categorical_accuracy: 0.9376 - val_loss: 2.1324 - val_categorical_accuracy: 0.5674
# Epoch 9/10
# 134/134 [==============================] - 1s 7ms/step - loss: 0.1983 - categorical_accuracy: 0.9372 - val_loss: 2.2571 - val_categorical_accuracy: 0.5665
# Epoch 10/10
# 134/134 [==============================] - 1s 7ms/step - loss: 0.1892 - categorical_accuracy: 0.9396 - val_loss: 2.3678 - val_categorical_accuracy: 0.5782
# varimp_30.csv
# selecting features
# trainX shape == (127, 8, 25).
# trainY shape == (127, 8, 4).
# 4/4 [==============================] - 1s 4ms/step
# (127, 2, 4)
# [[44  8  2  0]
#  [18 68 10  2]
#  [ 2 32 25 12]
#  [ 0  2 12 17]]
# 0.6062992125984252
# varimp_28.csv
# trainX shape == (2159, 10, 121).
# trainY shape == (2159, 10, 4).
# Epoch 1/10
# 108/108 [==============================] - 5s 13ms/step - loss: 0.8993 - categorical_accuracy: 0.6316 - val_loss: 1.3349 - val_categorical_accuracy: 0.5623
# Epoch 2/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.4164 - categorical_accuracy: 0.8485 - val_loss: 1.1928 - val_categorical_accuracy: 0.6641
# Epoch 3/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.2288 - categorical_accuracy: 0.9287 - val_loss: 1.4408 - val_categorical_accuracy: 0.6674
# Epoch 4/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1699 - categorical_accuracy: 0.9458 - val_loss: 1.6734 - val_categorical_accuracy: 0.6618
# Epoch 5/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1329 - categorical_accuracy: 0.9573 - val_loss: 1.8377 - val_categorical_accuracy: 0.6611
# Epoch 6/10
# 108/108 [==============================] - 1s 8ms/step - loss: 0.1054 - categorical_accuracy: 0.9654 - val_loss: 2.0358 - val_categorical_accuracy: 0.6525
# Epoch 7/10
# 108/108 [==============================] - 1s 8ms/step - loss: 0.1015 - categorical_accuracy: 0.9655 - val_loss: 2.4760 - val_categorical_accuracy: 0.6160
# Epoch 8/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0766 - categorical_accuracy: 0.9761 - val_loss: 2.5852 - val_categorical_accuracy: 0.6336
# Epoch 9/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0827 - categorical_accuracy: 0.9749 - val_loss: 2.0575 - val_categorical_accuracy: 0.6579
# Epoch 10/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0546 - categorical_accuracy: 0.9835 - val_loss: 2.5283 - val_categorical_accuracy: 0.6410
# varimp_28.csv
# trainX shape == (127, 10, 121).
# trainY shape == (127, 10, 4).
# 4/4 [==============================] - 1s 4ms/step
# (127, 2, 4)
# [[44  8  2  0]
#  [17 59 10 12]
#  [ 2 28 31 10]
#  [ 0  3  3 25]]
# 0.6259842519685039

# %%
def plot_learning_curves(run):
  history = run[0].history
  plt.plot([(1-z)*100 for z in history.history['categorical_accuracy']])
  plt.plot([(1-z)*100 for z in history.history['val_categorical_accuracy']])
  #plt.title('model 1 train and validation accuracy')
  plt.ylabel('Misclassification rate in %')
  plt.xlabel('Epoch')
  #plt.legend(['Training', 'Validation'], loc='upper left')
  #plt.legend('')
  plt.show()

trainX, trainY = generate_shifted_sequence(4,2,10, "train")
model_4_10_sh = train_models(4,10,50,75,20,"tanh",0.4,"Adam",16,50,"LLDDO")
plot_learning_curves(model_4_10_sh)
# Out:
# varimp_34.csv
# selecting features
# trainX shape == (3683, 4, 10).
# trainY shape == (3683, 4, 4).
# Epoch 1/50
# 185/185 [==============================] - 11s 11ms/step - loss: 1.1172 - categorical_accuracy: 0.4982 - val_loss: 0.9673 - val_categorical_accuracy: 0.6102
# Epoch 2/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.8602 - categorical_accuracy: 0.6295 - val_loss: 0.8227 - val_categorical_accuracy: 0.6808
# Epoch 3/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.7618 - categorical_accuracy: 0.6816 - val_loss: 0.9045 - val_categorical_accuracy: 0.6696
# Epoch 4/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.6856 - categorical_accuracy: 0.7127 - val_loss: 0.9253 - val_categorical_accuracy: 0.6696
# Epoch 5/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.6300 - categorical_accuracy: 0.7451 - val_loss: 1.0482 - val_categorical_accuracy: 0.6445
# Epoch 6/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.5993 - categorical_accuracy: 0.7599 - val_loss: 1.0857 - val_categorical_accuracy: 0.6275
# Epoch 7/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.5561 - categorical_accuracy: 0.7798 - val_loss: 1.0862 - val_categorical_accuracy: 0.6584
# Epoch 8/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.5303 - categorical_accuracy: 0.7962 - val_loss: 1.1626 - val_categorical_accuracy: 0.6472
# Epoch 9/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.4897 - categorical_accuracy: 0.8148 - val_loss: 1.2004 - val_categorical_accuracy: 0.6662
# Epoch 10/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4682 - categorical_accuracy: 0.8193 - val_loss: 1.2790 - val_categorical_accuracy: 0.6669
# Epoch 11/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4494 - categorical_accuracy: 0.8316 - val_loss: 1.3133 - val_categorical_accuracy: 0.6598
# Epoch 12/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4289 - categorical_accuracy: 0.8428 - val_loss: 1.3762 - val_categorical_accuracy: 0.6425
# Epoch 13/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4156 - categorical_accuracy: 0.8448 - val_loss: 1.4036 - val_categorical_accuracy: 0.6482
# Epoch 14/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.3922 - categorical_accuracy: 0.8540 - val_loss: 1.4595 - val_categorical_accuracy: 0.6343
# Epoch 15/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.3753 - categorical_accuracy: 0.8618 - val_loss: 1.5452 - val_categorical_accuracy: 0.6438
# Epoch 16/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.3895 - categorical_accuracy: 0.8601 - val_loss: 1.4693 - val_categorical_accuracy: 0.6394
# Epoch 17/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.3542 - categorical_accuracy: 0.8763 - val_loss: 1.6077 - val_categorical_accuracy: 0.6286
# Epoch 18/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.3399 - categorical_accuracy: 0.8776 - val_loss: 1.6335 - val_categorical_accuracy: 0.6421
# Epoch 19/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.3289 - categorical_accuracy: 0.8833 - val_loss: 1.6639 - val_categorical_accuracy: 0.6506
# Epoch 20/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.3204 - categorical_accuracy: 0.8869 - val_loss: 1.7599 - val_categorical_accuracy: 0.6299
# Epoch 21/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.3096 - categorical_accuracy: 0.8891 - val_loss: 1.7307 - val_categorical_accuracy: 0.6238
# Epoch 22/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.3083 - categorical_accuracy: 0.8923 - val_loss: 1.7355 - val_categorical_accuracy: 0.6479
# Epoch 23/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.3076 - categorical_accuracy: 0.8923 - val_loss: 1.7706 - val_categorical_accuracy: 0.6472
# Epoch 24/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2991 - categorical_accuracy: 0.8949 - val_loss: 1.7449 - val_categorical_accuracy: 0.6408
# Epoch 25/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2885 - categorical_accuracy: 0.8954 - val_loss: 1.7216 - val_categorical_accuracy: 0.6713
# Epoch 26/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2871 - categorical_accuracy: 0.8966 - val_loss: 1.9064 - val_categorical_accuracy: 0.6248
# Epoch 27/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.2806 - categorical_accuracy: 0.8996 - val_loss: 1.8474 - val_categorical_accuracy: 0.6292
# Epoch 28/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2644 - categorical_accuracy: 0.9074 - val_loss: 1.8716 - val_categorical_accuracy: 0.6316
# Epoch 29/50
# 185/185 [==============================] - 1s 6ms/step - loss: 0.2672 - categorical_accuracy: 0.9079 - val_loss: 1.8371 - val_categorical_accuracy: 0.6275
# Epoch 30/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2897 - categorical_accuracy: 0.9005 - val_loss: 1.8265 - val_categorical_accuracy: 0.6438
# Epoch 31/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2599 - categorical_accuracy: 0.9096 - val_loss: 1.8663 - val_categorical_accuracy: 0.6303
# Epoch 32/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2508 - categorical_accuracy: 0.9126 - val_loss: 1.9794 - val_categorical_accuracy: 0.6486
# Epoch 33/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2513 - categorical_accuracy: 0.9115 - val_loss: 1.9706 - val_categorical_accuracy: 0.6333
# Epoch 34/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2410 - categorical_accuracy: 0.9178 - val_loss: 1.9918 - val_categorical_accuracy: 0.6462
# Epoch 35/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2451 - categorical_accuracy: 0.9137 - val_loss: 1.9132 - val_categorical_accuracy: 0.6509
# Epoch 36/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2501 - categorical_accuracy: 0.9111 - val_loss: 1.9214 - val_categorical_accuracy: 0.6452
# Epoch 37/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2388 - categorical_accuracy: 0.9157 - val_loss: 2.0021 - val_categorical_accuracy: 0.6306
# Epoch 38/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2353 - categorical_accuracy: 0.9181 - val_loss: 2.0576 - val_categorical_accuracy: 0.6367
# Epoch 39/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2274 - categorical_accuracy: 0.9234 - val_loss: 2.0632 - val_categorical_accuracy: 0.6303
# Epoch 40/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2308 - categorical_accuracy: 0.9189 - val_loss: 2.0303 - val_categorical_accuracy: 0.6482
# Epoch 41/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2209 - categorical_accuracy: 0.9266 - val_loss: 2.0680 - val_categorical_accuracy: 0.6286
# Epoch 42/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2186 - categorical_accuracy: 0.9228 - val_loss: 2.1681 - val_categorical_accuracy: 0.6343
# Epoch 43/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2228 - categorical_accuracy: 0.9246 - val_loss: 2.0264 - val_categorical_accuracy: 0.6425
# Epoch 44/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2211 - categorical_accuracy: 0.9224 - val_loss: 1.9643 - val_categorical_accuracy: 0.6486
# Epoch 45/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2137 - categorical_accuracy: 0.9260 - val_loss: 2.1784 - val_categorical_accuracy: 0.6238
# Epoch 46/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2092 - categorical_accuracy: 0.9285 - val_loss: 2.1509 - val_categorical_accuracy: 0.6360
# Epoch 47/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2142 - categorical_accuracy: 0.9260 - val_loss: 2.2138 - val_categorical_accuracy: 0.6303
# Epoch 48/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2043 - categorical_accuracy: 0.9313 - val_loss: 2.2068 - val_categorical_accuracy: 0.6306
# Epoch 49/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2027 - categorical_accuracy: 0.9317 - val_loss: 2.1897 - val_categorical_accuracy: 0.6340
# Epoch 50/50
# 185/185 [==============================] - 1s 7ms/step - loss: 0.2129 - categorical_accuracy: 0.9263 - val_loss: 2.1842 - val_categorical_accuracy: 0.6326
